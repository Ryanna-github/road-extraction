# %%
import data_loader
import model
import loss
import solver

import torch
from torch import optim, nn
from tqdm import tqdm
from torchsummary import summary

# %%
root_path = '/home/renyan/ossdata/massachusetts-roads-dataset/'
road_path = root_path + "tiff_select2_parts_16/"
BATCH_SIZE = 4
LR = 0.0005
EPOCH_NUM = 20

# %% [markdown]
# ## U-Net

# %%
INPUT_SIZE, OUTPUT_SIZE = 256, 68
train_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, True)
val_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, False)
# Out:
# Train set: True
# Count: 7056 pairs
# Train set: False
# Count: 224 pairs

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = model.UNet().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(params = net.parameters(), lr = LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5)
unet_sv = solver.Solver(device, net, train_dataset, val_dataset, criterion, LR, BATCH_SIZE, optimizer, scheduler, "U-Net")
summary(net, (3, 256, 256))
# Out:
# Net U-Net initialized.
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 254, 254]           1,792
#        BatchNorm2d-2         [-1, 64, 254, 254]             128
#               ReLU-3         [-1, 64, 254, 254]               0
#             Conv2d-4         [-1, 64, 252, 252]          36,928
#        BatchNorm2d-5         [-1, 64, 252, 252]             128
#               ReLU-6         [-1, 64, 252, 252]               0
#         DoubleConv-7         [-1, 64, 252, 252]               0
#          MaxPool2d-8         [-1, 64, 126, 126]               0
#             Conv2d-9        [-1, 128, 124, 124]          73,856
#       BatchNorm2d-10        [-1, 128, 124, 124]             256
#              ReLU-11        [-1, 128, 124, 124]               0
#            Conv2d-12        [-1, 128, 122, 122]         147,584
#       BatchNorm2d-13        [-1, 128, 122, 122]             256
#              ReLU-14        [-1, 128, 122, 122]               0
#        DoubleConv-15        [-1, 128, 122, 122]               0
#              Down-16        [-1, 128, 122, 122]               0
#         MaxPool2d-17          [-1, 128, 61, 61]               0
#            Conv2d-18          [-1, 256, 59, 59]         295,168
#       BatchNorm2d-19          [-1, 256, 59, 59]             512
#              ReLU-20          [-1, 256, 59, 59]               0
#            Conv2d-21          [-1, 256, 57, 57]         590,080
#       BatchNorm2d-22          [-1, 256, 57, 57]             512
#              ReLU-23          [-1, 256, 57, 57]               0
#        DoubleConv-24          [-1, 256, 57, 57]               0
#              Down-25          [-1, 256, 57, 57]               0
#         MaxPool2d-26          [-1, 256, 28, 28]               0
#            Conv2d-27          [-1, 512, 26, 26]       1,180,160
#       BatchNorm2d-28          [-1, 512, 26, 26]           1,024
#              ReLU-29          [-1, 512, 26, 26]               0
#            Conv2d-30          [-1, 512, 24, 24]       2,359,808
#       BatchNorm2d-31          [-1, 512, 24, 24]           1,024
#              ReLU-32          [-1, 512, 24, 24]               0
#        DoubleConv-33          [-1, 512, 24, 24]               0
#              Down-34          [-1, 512, 24, 24]               0
#         MaxPool2d-35          [-1, 512, 12, 12]               0
#            Conv2d-36          [-1, 512, 10, 10]       2,359,808
#       BatchNorm2d-37          [-1, 512, 10, 10]           1,024
#              ReLU-38          [-1, 512, 10, 10]               0
#            Conv2d-39            [-1, 512, 8, 8]       2,359,808
#       BatchNorm2d-40            [-1, 512, 8, 8]           1,024
#              ReLU-41            [-1, 512, 8, 8]               0
#        DoubleConv-42            [-1, 512, 8, 8]               0
#              Down-43            [-1, 512, 8, 8]               0
#          Upsample-44          [-1, 512, 16, 16]               0
#            Conv2d-45          [-1, 512, 14, 14]       4,719,104
#       BatchNorm2d-46          [-1, 512, 14, 14]           1,024
#              ReLU-47          [-1, 512, 14, 14]               0
#            Conv2d-48          [-1, 256, 12, 12]       1,179,904
#       BatchNorm2d-49          [-1, 256, 12, 12]             512
#              ReLU-50          [-1, 256, 12, 12]               0
#        DoubleConv-51          [-1, 256, 12, 12]               0
#                Up-52          [-1, 256, 12, 12]               0
#          Upsample-53          [-1, 256, 24, 24]               0
#            Conv2d-54          [-1, 256, 22, 22]       1,179,904
#       BatchNorm2d-55          [-1, 256, 22, 22]             512
#              ReLU-56          [-1, 256, 22, 22]               0
#            Conv2d-57          [-1, 128, 20, 20]         295,040
#       BatchNorm2d-58          [-1, 128, 20, 20]             256
#              ReLU-59          [-1, 128, 20, 20]               0
#        DoubleConv-60          [-1, 128, 20, 20]               0
#                Up-61          [-1, 128, 20, 20]               0
#          Upsample-62          [-1, 128, 40, 40]               0
#            Conv2d-63          [-1, 128, 38, 38]         295,040
#       BatchNorm2d-64          [-1, 128, 38, 38]             256
#              ReLU-65          [-1, 128, 38, 38]               0
#            Conv2d-66           [-1, 64, 36, 36]          73,792
#       BatchNorm2d-67           [-1, 64, 36, 36]             128
#              ReLU-68           [-1, 64, 36, 36]               0
#        DoubleConv-69           [-1, 64, 36, 36]               0
#                Up-70           [-1, 64, 36, 36]               0
#          Upsample-71           [-1, 64, 72, 72]               0
#            Conv2d-72           [-1, 64, 70, 70]          73,792
#       BatchNorm2d-73           [-1, 64, 70, 70]             128
#              ReLU-74           [-1, 64, 70, 70]               0
#            Conv2d-75           [-1, 64, 68, 68]          36,928
#       BatchNorm2d-76           [-1, 64, 68, 68]             128
#              ReLU-77           [-1, 64, 68, 68]               0
#        DoubleConv-78           [-1, 64, 68, 68]               0
#                Up-79           [-1, 64, 68, 68]               0
#            Conv2d-80            [-1, 1, 68, 68]              65
#           OutConv-81            [-1, 1, 68, 68]               0
# ================================================================
# Total params: 17,267,393
# Trainable params: 17,267,393
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 464.10
# Params size (MB): 65.87
# Estimated Total Size (MB): 530.72
# ----------------------------------------------------------------

# %%
unet_sv.train(epochs = EPOCH_NUM, save_cp = True, dir_checkpoint = 'checkpoints/', prefix = 'thesis_unet')
# Out:
# Epoch 1/20: 100%|██████████| 7056/7056 [19:55<00:00,  5.90img/s, loss (batch)=0.56]
# Epoch 2/20: 100%|██████████| 7056/7056 [20:38<00:00,  5.70img/s, loss (batch)=0.347]
# Epoch 3/20: 100%|██████████| 7056/7056 [21:07<00:00,  5.57img/s, loss (batch)=0.433]
# Epoch 4/20: 100%|██████████| 7056/7056 [21:02<00:00,  5.59img/s, loss (batch)=0.291]
# Epoch 5/20: 100%|██████████| 7056/7056 [19:53<00:00,  5.91img/s, loss (batch)=0.32]
# Epoch 6/20: 100%|██████████| 7056/7056 [19:21<00:00,  6.07img/s, loss (batch)=0.329]
# Epoch 7/20:  56%|█████▌    | 3924/7056 [10:47<06:50,  7.63img/s, loss (batch)=0.306]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 8/20: 100%|██████████| 7056/7056 [19:00<00:00,  6.19img/s, loss (batch)=0.355]
# Epoch 9/20: 100%|██████████| 7056/7056 [19:07<00:00,  6.15img/s, loss (batch)=0.481]
# Epoch 10/20:  32%|███▏      | 2224/7056 [06:01<10:13,  7.88img/s, loss (batch)=0.344]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 11/20: 100%|██████████| 7056/7056 [19:02<00:00,  6.17img/s, loss (batch)=0.406]
# Epoch 12/20:  51%|█████     | 3616/7056 [09:32<07:23,  7.75img/s, loss (batch)=0.399]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 13/20: 100%|██████████| 7056/7056 [18:59<00:00,  6.19img/s, loss (batch)=0.308]
# Epoch 14/20:  64%|██████▎   | 4488/7056 [11:27<05:12,  8.21img/s, loss (batch)=0.362]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 15/20: 100%|██████████| 7056/7056 [18:08<00:00,  6.48img/s, loss (batch)=0.384]
# Epoch 16/20:  81%|████████  | 5716/7056 [14:53<03:01,  7.37img/s, loss (batch)=0.317]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 18/20: 100%|█████████▉| 7032/7056 [18:32<00:02,  8.19img/s, loss (batch)=0.318]  IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#
# Epoch 20/20: 100%|██████████| 7056/7056 [18:13<00:00,  6.45img/s, loss (batch)=0.4]

# %% [markdown]
# ## LinkNet

# %%
INPUT_SIZE, OUTPUT_SIZE = 256, 256
train_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, True)
val_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = model.LinkNet34().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(params = net.parameters(), lr = LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5)
linknet_sv = solver.Solver(device, net, train_dataset, val_dataset, criterion, LR, BATCH_SIZE, optimizer, scheduler, "LinkNet34")
summary(net, (3, 256, 256))
# Out:
# Net LinkNet34 initialized.
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#          MaxPool2d-4           [-1, 64, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#        BasicBlock-11           [-1, 64, 64, 64]               0
#            Conv2d-12           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-13           [-1, 64, 64, 64]             128
#              ReLU-14           [-1, 64, 64, 64]               0
#            Conv2d-15           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-16           [-1, 64, 64, 64]             128
#              ReLU-17           [-1, 64, 64, 64]               0
#        BasicBlock-18           [-1, 64, 64, 64]               0
#            Conv2d-19           [-1, 64, 64, 64]          36,864
#       BatchNorm2d
[-1, 256, 16, 16]         589,824
#       BatchNorm2d-90          [-1, 256, 16, 16]             512
#              ReLU-91          [-1, 256, 16, 16]               0
#        BasicBlock-92          [-1, 256, 16, 16]               0
#            Conv2d-93          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-94          [-1, 256, 16, 16]             512
#              ReLU-95          [-1, 256, 16, 16]               0
#            Conv2d-96          [-1, 256, 16, 16]         589,824
#       BatchNorm2d-97          [-1, 256, 16, 16]             512
#              ReLU-98          [-1, 256, 16, 16]               0
#        BasicBlock-99          [-1, 256, 16, 16]               0
#           Conv2d-100            [-1, 512, 8, 8]       1,179,648
#      BatchNorm2d-101            [-1, 512, 8, 8]           1,024
#             ReLU-102            [-1, 512, 8, 8]               0
#           Conv2d-103            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-104            [-1, 512, 8, 8]           1,024
#           Conv2d-105            [-1, 512, 8, 8]         131,072
#      BatchNorm2d-106            [-1, 512, 8, 8]           1,024
#             ReLU-107            [-1, 512, 8, 8]               0
#       BasicBlock-108            [-1, 512, 8, 8]               0
#           Conv2d-109            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-110            [-1, 512, 8, 8]           1,024
#             ReLU-111            [-1, 512, 8, 8]               0
#           Conv2d-112            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-113            [-1, 512, 8, 8]           1,024
#             ReLU-114            [-1, 512, 8, 8]               0
#       BasicBlock-115            [-1, 512, 8, 8]               0
#           Conv2d-116            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-117            [-1, 512, 8, 8]           1,024
#             ReLU-118            [-1, 512, 8, 8]               0
#           Conv2d-119            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-120            [-1, 512, 8, 8]           1,024
#             ReLU-121            [-1, 512, 8, 8]               0
#       BasicBlock-122            [-1, 512, 8, 8]               0
#           Conv2d-123            [-1, 128, 8, 8]          65,664
#      BatchNorm2d-124            [-1, 128, 8, 8]             256
#  ConvTranspose2d-125          [-1, 128, 16, 16]         147,584
#      BatchNorm2d-126          [-1, 128, 16, 16]             256
#           Conv2d-127          [-1, 256, 16, 16]          33,024
#      BatchNorm2d-128          [-1, 256, 16, 16]             512
#     DecoderBlock-129          [-1, 256, 16, 16]               0
#           Conv2d-130           [-1, 64, 16, 16]          16,448
#      BatchNorm2d-131           [-1, 64, 16, 16]             128
#  ConvTranspose2d-132           [-1, 64, 32, 32]          36,928
#      BatchNorm2d-133           [-1, 64, 32, 32]             128
#           Conv2d-134          [-1, 128, 32, 32]           8,320
#      BatchNorm2d-135          [-1, 128, 32, 32]             256
#     DecoderBlock-136          [-1, 128, 32, 32]               0
#           Conv2d-137           [-1, 32, 32, 32]           4,128
#      BatchNorm2d-138           [-1, 32, 32, 32]              64
#  ConvTranspose2d-139           [-1, 32, 64, 64]           9,248
#      BatchNorm2d-140           [-1, 32, 64, 64]              64
#           Conv2d-141           [-1, 64, 64, 64]           2,112
#      BatchNorm2d-142           [-1, 64, 64, 64]             128
#     DecoderBlock-143           [-1, 64, 64, 64]               0
#           Conv2d-144           [-1, 16, 64, 64]           1,040
#      BatchNorm2d-145           [-1, 16, 64, 64]              32
#  ConvTranspose2d-146         [-1, 16, 128, 128]           2,320
#      BatchNorm2d-147         [-1, 16, 128, 128]              32
#           Conv2d-148         [-1, 64, 128, 128]           1,088
#      BatchNorm2d-149         [-1, 64, 128, 128]             128
#     DecoderBlock-150         [-1, 64, 128, 128]               0
#  ConvTranspose2d-151         [-1, 32, 257, 257]          18,464
#           Conv2d-152         [-1, 32, 255, 255]           9,248
#           Conv2d-153          [-1, 1, 256, 256]             129
# ================================================================
# Total params: 21,642,401
# Trainable params: 21,642,401
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 202.13
# Params size (MB): 82.56
# Estimated Total Size (MB): 285.43
# ----------------------------------------------------------------

# %%
linknet_sv.train(epochs = EPOCH_NUM, save_cp = True, dir_checkpoint = 'checkpoints/', prefix = 'thesis_linknet')

# %% [markdown]
# ## D-LinkNet

# %%
INPUT_SIZE, OUTPUT_SIZE = 256, 256
train_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, True)
val_dataset = data_loader.RoadDataset(road_path, INPUT_SIZE, OUTPUT_SIZE, False)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
net = model.DLinkNet34().to(device)
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(params = net.parameters(), lr = LR)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience = 5)
dlinknet_sv = solver.Solver(device, net, train_dataset, val_dataset, criterion, LR, BATCH_SIZE, optimizer, scheduler, "DLinkNet34")
summary(net, (3, 256, 256))
# Out:
# Net DLinkNet34 initialized.
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 128, 128]           9,408
#        BatchNorm2d-2         [-1, 64, 128, 128]             128
#               ReLU-3         [-1, 64, 128, 128]               0
#          MaxPool2d-4           [-1, 64, 64, 64]               0
#             Conv2d-5           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-6           [-1, 64, 64, 64]             128
#               ReLU-7           [-1, 64, 64, 64]               0
#             Conv2d-8           [-1, 64, 64, 64]          36,864
#        BatchNorm2d-9           [-1, 64, 64, 64]             128
#              ReLU-10           [-1, 64, 64, 64]               0
#        BasicBlock-11           [-1, 64, 64, 64]               0
#            Conv2d-12           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-13           [-1, 64, 64, 64]             128
#              ReLU-14           [-1, 64, 64, 64]               0
#            Conv2d-15           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-16           [-1, 64, 64, 64]             128
#              ReLU-17           [-1, 64, 64, 64]               0
#        BasicBlock-18           [-1, 64, 64, 64]               0
#            Conv2d-19           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-20           [-1, 64, 64, 64]             128
#              ReLU-21           [-1, 64, 64, 64]               0
#            Conv2d-22           [-1, 64, 64, 64]          36,864
#       BatchNorm2d-23           [-1, 64, 64, 64]             128
#              ReLU-24           [-1, 64, 64, 64]               0
#        BasicBlock-25           [-1, 64, 64, 64]               0
#            Conv2d-26          [-1, 128, 32, 32]          73,728
#       BatchNorm2d-27          [-1, 128, 32, 32]             256
#              ReLU-28          [-1, 128, 32, 32]               0
#            Conv2d-29          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-30          [-1, 128, 32, 32]             256
#            Conv2d-31          [-1, 128, 32, 32]           8,192
#       BatchNorm2d-32          [-1, 128, 32, 32]             256
#              ReLU-33          [-1, 128, 32, 32]               0
#        BasicBlock-34          [-1, 128, 32, 32]               0
#            Conv2d-35          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-36          [-1, 128, 32, 32]             256
#              ReLU-37          [-1, 128, 32, 32]               0
#            Conv2d-38          [-1, 128, 32, 32]         147,456
#       BatchNorm2d-39          [-1, 128, 32, 32]             256
#              ReLU-40          [-1, 128, 32, 32]               0
#        BasicBlock-41          [-1, 128, 32, 32]               0
#            Conv2d-42          [-1, 128, 32, 32]         147,456
#       BatchNorm2d
[-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-110            [-1, 512, 8, 8]           1,024
#             ReLU-111            [-1, 512, 8, 8]               0
#           Conv2d-112            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-113            [-1, 512, 8, 8]           1,024
#             ReLU-114            [-1, 512, 8, 8]               0
#       BasicBlock-115            [-1, 512, 8, 8]               0
#           Conv2d-116            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-117            [-1, 512, 8, 8]           1,024
#             ReLU-118            [-1, 512, 8, 8]               0
#           Conv2d-119            [-1, 512, 8, 8]       2,359,296
#      BatchNorm2d-120            [-1, 512, 8, 8]           1,024
#             ReLU-121            [-1, 512, 8, 8]               0
#       BasicBlock-122            [-1, 512, 8, 8]               0
#           Conv2d-123            [-1, 512, 8, 8]       2,359,808
#           Conv2d-124            [-1, 512, 8, 8]       2,359,808
#           Conv2d-125            [-1, 512, 8, 8]       2,359,808
#           Conv2d-126            [-1, 512, 8, 8]       2,359,808
#           Dblock-127            [-1, 512, 8, 8]               0
#           Conv2d-128            [-1, 128, 8, 8]          65,664
#      BatchNorm2d-129            [-1, 128, 8, 8]             256
#  ConvTranspose2d-130          [-1, 128, 16, 16]         147,584
#      BatchNorm2d-131          [-1, 128, 16, 16]             256
#           Conv2d-132          [-1, 256, 16, 16]          33,024
#      BatchNorm2d-133          [-1, 256, 16, 16]             512
#     DecoderBlock-134          [-1, 256, 16, 16]               0
#           Conv2d-135           [-1, 64, 16, 16]          16,448
#      BatchNorm2d-136           [-1, 64, 16, 16]             128
#  ConvTranspose2d-137           [-1, 64, 32, 32]          36,928
#      BatchNorm2d-138           [-1, 64, 32, 32]             128
#           Conv2d-139          [-1, 128, 32, 32]           8,320
#      BatchNorm2d-140          [-1, 128, 32, 32]             256
#     DecoderBlock-141          [-1, 128, 32, 32]               0
#           Conv2d-142           [-1, 32, 32, 32]           4,128
#      BatchNorm2d-143           [-1, 32, 32, 32]              64
#  ConvTranspose2d-144           [-1, 32, 64, 64]           9,248
#      BatchNorm2d-145           [-1, 32, 64, 64]              64
#           Conv2d-146           [-1, 64, 64, 64]           2,112
#      BatchNorm2d-147           [-1, 64, 64, 64]             128
#     DecoderBlock-148           [-1, 64, 64, 64]               0
#           Conv2d-149           [-1, 16, 64, 64]           1,040
#      BatchNorm2d-150           [-1, 16, 64, 64]              32
#  ConvTranspose2d-151         [-1, 16, 128, 128]           2,320
#      BatchNorm2d-152         [-1, 16, 128, 128]              32
#           Conv2d-153         [-1, 64, 128, 128]           1,088
#      BatchNorm2d-154         [-1, 64, 128, 128]             128
#     DecoderBlock-155         [-1, 64, 128, 128]               0
#  ConvTranspose2d-156         [-1, 32, 256, 256]          32,800
#           Conv2d-157         [-1, 32, 256, 256]           9,248
#           Conv2d-158          [-1, 1, 256, 256]             289
# ================================================================
# Total params: 31,096,129
# Trainable params: 31,096,129
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 203.38
# Params size (MB): 118.62
# Estimated Total Size (MB): 322.75
# ----------------------------------------------------------------

# %%
dlinknet_sv.train(epochs = EPOCH_NUM, save_cp = True, dir_checkpoint = 'checkpoints/', prefix = 'thesis_dlinknet')
